# %% [markdown]
# # **Processamento de Linguagem Natural [2023.Q3]**
# Prof. Alexandre Donizeti Alves

# %% [markdown]
# ### **ATIVIDADE PRÁTICA 04 [Uso da API da OpenAI com técnicas de PLN]**

# %% [markdown]
# A **ATIVIDADE PRÁTICA 04** deve ser feita utilizando o **Google Colab** com uma conta sua vinculada ao Gmail. O link do seu notebook, armazenado no Google Drive, além do link de um repositório no GitHub e os principais resultados da atividade, devem ser enviados usando o seguinte formulário:
#
# > https://forms.gle/GzwCq3R7ExtE9g9a8
#
#
# **IMPORTANTE**: A submissão deve ser feita até o dia **26/11 (domingo)** APENAS POR UM INTEGRANTE DA EQUIPE, até às 23h59. Por favor, lembre-se de dar permissão de ACESSO IRRESTRITO para o professor da disciplina de PLN.

# %% [markdown]
# ### **EQUIPE**
#
# ---

# %% [markdown]
# **POR FAVOR, PREENCHER OS INTEGRANDES DA SUA EQUIPE:**
#
#
# **Integrante 01:**
#
# `Por favor, informe o seu nome completo e RA:` Leonardo Galan Guerra | 11202130382
#
# **Integrante 02:**
#
# `Por favor, informe o seu nome completo e RA:`
#
# **Integrante 03:**
#
# `Por favor, informe o seu nome completo e RA:`

# %% [markdown]
# ### **LIVRO**
# ---

# %% [markdown]
# `Processamento de Linguagem Natural - Conceitos, Técnicas e Aplicações em Português.`
#
# >
#
# Disponível gratuitamente em:
#
#   > https://brasileiraspln.com/livro-pln/1a-edicao/.
#
#
# **POR FAVOR, PREENCHER OS CAPITULOS SELECIONADOS PARA A SUA EQUIPE:**
#
# `Primeiro capítulo: ` https://brasileiraspln.com/livro-pln/1a-edicao/parte2/cap2/cap2.html
#
# `Segundo capítulo:` https://brasileiraspln.com/livro-pln/1a-edicao/parte9/cap23/cap23.html

# %% [markdown]
# ### **DESCRIÇÃO**
# ---

# %% [markdown]
# Implementar um `notebook` no `Google Colab` que faça uso da **API da OpenAI** aplicando, no mínimo, 3 técnicas de PLN. As técnicas devem ser aplicadas nos 2 (DOIS) capítulos do livro **Processamento de Linguagem Natural - Conceitos, Técnicas e Aplicações em Português**.
#
# >
#
# **RESTRIÇÃO**: É obrigatório usar o *endpoint* "*`Chat Completions`*".
#
# >
#
# As seguintes técnicas de PLN podem ser usadas:
#
# *   Correção Gramatical
# *   Classificação de Textos
# *   Análise de Sentimentos
# *   Detecção de Emoções
# *   Extração de Palavras-chave
# *   Tradução de Textos
# *   Sumarização de Textos
# *   **Similaridade de Textos**
# *   **Reconhecimento de Entidades Nomeadas**
# *   **Sistemas de Perguntas e Respostas**
#
# >
#
# Os capítulos devem ser os mesmos selecionados na **ATIVIDADE PRÁTICA 02**. Para consultar os capítulos, considere a seguinte planilha:
#
# >
#
# > https://docs.google.com/spreadsheets/d/1ZutzQ3v1OJgsgzCvCwxXlRIQ3ChXNlHNvB63JQvYsbo/edit?usp=sharing
#
# >
# >
#
# **IMPORTANTE:** É obrigatório usar o e-mail da UFABC. Não é permitido alterar os capítulos já selecionados.

# %% [markdown]
# ### **CRITÉRIOS DE AVALIAÇÃO**
# ---

# %% [markdown]
# Serão considerados como critérios de avaliação as técnicas usadas e a criatividade envolvida na aplicação das mesmas.

# %% [markdown]
# ### **IMPLEMENTAÇÃO**
# ---

# %%
# !pip install openai==0.28.1

# %%
# TÉCNICA 1: CORREÇÃO GRAMATICAL PARA O CAPÍTULO 2 E CAPÍTULO 23.
import openai
import requests
import json

openai.api_key = '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'
endpoint = "https://api.openai.com/v1/chat/completions"

def obter_texto_do_link(url):
    resposta = requests.get(url)
    texto = resposta.text
    return texto

#Necessário dividir em partes menores, pois, estava dando erro de execução: Request too large for gpt-3.5-turbo-0613 in organization org-xS9uXjEyvjfRTEj05U0AnHBh on tokens per min (TPM): Limit 40000, Requested 42644.
def dividir_texto_em_partes(texto, tamanho_maximo):
    partes = [texto[i:i+tamanho_maximo] for i in range(0, len(texto), tamanho_maximo)]
    return partes

capitulo_2_url = "https://brasileiraspln.com/livro-pln/1a-edicao/parte2/cap2/cap2.html"
capitulo_2_texto = obter_texto_do_link(capitulo_2_url)

capitulo_23_url = "https://brasileiraspln.com/livro-pln/1a-edicao/parte9/cap23/cap23.html"
capitulo_23_texto = obter_texto_do_link(capitulo_23_url)

mensagem_sistema_2_1 = "Você é um assistente de correção gramatical."
mensagem_usuario_2_1 = f"Texto do Capítulo 2: {capitulo_2_texto} Tem alguns erros de gramática."
mensagem_assistente_2_1 = ""

mensagem_sistema_23_1 = "Você é um assistente de correção gramatical."
mensagem_usuario_23_1 = f"Texto do Capítulo 23: {capitulo_23_texto} Tem alguns erros de gramática."
mensagem_assistente_23_1 = ""

partes_capitulo_2 = dividir_texto_em_partes(capitulo_2_texto, 2000)
partes_capitulo_23 = dividir_texto_em_partes(capitulo_23_texto, 2000)

parametros_2_1 = {
    "model": "gpt-3.5-turbo-0613",
    "messages": [
        {"role": "system", "content": mensagem_sistema_2_1},
        {"role": "user", "content": mensagem_usuario_2_1},
        {"role": "assistant", "content": mensagem_assistente_2_1}
    ]
}

parametros_23_1 = {
    "model": "gpt-3.5-turbo-0613",
    "messages": [
        {"role": "system", "content": mensagem_sistema_23_1},
        {"role": "user", "content": mensagem_usuario_23_1},
        {"role": "assistant", "content": mensagem_assistente_23_1}
    ]
}

# Enviar cada parte do texto como uma mensagem separada
for parte in partes_capitulo_2:
    parametros_2_1["messages"][1]["content"] = f"Texto do Capítulo 2: {parte} Tem alguns erros de gramática."
    resposta_correcao_gramatical_2 = requests.post(endpoint, json=parametros_2_1, headers={"Authorization": f"Bearer {openai.api_key}"}).json()
    print("Resposta Correção Gramatical para Capítulo 2:", resposta_correcao_gramatical_2)

for parte in partes_capitulo_23:
    parametros_23_1["messages"][1]["content"] = f"Texto do Capítulo 23: {parte} Tem alguns erros de gramática."
    resposta_correcao_gramatical_23 = requests.post(endpoint, json=parametros_23_1, headers={"Authorization": f"Bearer {openai.api_key}"}).json()
    print("Resposta Correção Gramatical para Capítulo 23:", resposta_correcao_gramatical_23)
# Out:
# Resposta Correção Gramatical para Capítulo 2: {'id': 'chatcmpl-8Ozb8YVHZTwHRk8xyltoO2DseBafh', 'object': 'chat.completion', 'created': 1700967346, 'model': 'gpt-3.5-turbo-0613', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': 'O texto contém alguns erros de gramática. Aqui estão as correções:\n\nNo título:\n- "Processamento de Linguagem Natural - 2&nbsp; Texto ou fala?" deve ser "Processamento de Linguagem Natural - 2: Texto ou fala?"\n\nNo cabeçalho HTML:\n- A linha `<html xmlns="http://www.w3.org/1999/xhtml" lang="pt-BR" xml:lang="pt-BR"><head>` está correta.\n- A linha `<meta name="generator" content="quarto-1.3.433">` está correta.\n- A linha `<meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=yes">` está correta.\n\nNo meta author:\n- "Camila de AraÃºjo Azevedo" deve ser "Camila de Araújo Azevedo".\n- "Priscila OsÃ³rio CÃ´rtes" deve ser "Priscila Osório Côrtes".\n\nNo estilo CSS:\n- A linha `div.columns{display: flex; gap: mi
# ...

# %%
# TÉCNICA 2: SUMARIZAÇÃO DE TEXTOS PARA O CAPÍTULO 2 E CAPÍTULO 23.
import openai
import requests
import json

openai.api_key = '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'
endpoint = "https://api.openai.com/v1/chat/completions"

def obter_texto_do_link(url):
    resposta = requests.get(url)
    texto = resposta.text
    return texto

#Necessário pelo mesmo motivo da técnica 1.
def dividir_texto_em_partes(texto, tamanho_maximo):
    partes = [texto[i:i+tamanho_maximo] for i in range(0, len(texto), tamanho_maximo)]
    return partes

capitulo_2_url = "https://brasileiraspln.com/livro-pln/1a-edicao/parte2/cap2/cap2.html"
capitulo_2_texto = obter_texto_do_link(capitulo_2_url)

capitulo_23_url = "https://brasileiraspln.com/livro-pln/1a-edicao/parte9/cap23/cap23.html"
capitulo_23_texto = obter_texto_do_link(capitulo_23_url)

mensagem_sistema_2_2 = "Você é um assistente de sumarização de textos."
mensagem_usuario_2_2 = f"Texto do Capítulo 2: {capitulo_2_texto} Pode resumir?"
mensagem_assistente_2_2 = ""

parametros_2_2 = {
    "model": "gpt-3.5-turbo-0613",
    "messages": [
        {"role": "system", "content": mensagem_sistema_2_2},
        {"role": "user", "content": mensagem_usuario_2_2},
        {"role": "assistant", "content": mensagem_assistente_2_2}
    ]
}

mensagem_sistema_23_2 = "Você é um assistente de sumarização de textos."
mensagem_usuario_23_2 = f"Texto do Capítulo 23: {capitulo_23_texto} Pode resumir?"
mensagem_assistente_23_2 = ""

parametros_23_2 = {
    "model": "gpt-3.5-turbo-0613",
    "messages": [
        {"role": "system", "content": mensagem_sistema_23_2},
        {"role": "user", "content": mensagem_usuario_23_2},
        {"role": "assistant", "content": mensagem_assistente_23_2}
    ]
}

partes_capitulo_2 = dividir_texto_em_partes(capitulo_2_texto, 2000)
partes_capitulo_23 = dividir_texto_em_partes(capitulo_23_texto, 2000)

# Enviar cada parte do texto como uma mensagem separada
for parte in partes_capitulo_2:
    parametros_2_2["messages"][1]["content"] = f"Texto do Capítulo 2: {parte} Pode resumir?"
    resposta_sumarizacao_2 = requests.post(endpoint, json=parametros_2_2, headers={"Authorization": f"Bearer {openai.api_key}"}).json()
    print("Resposta Sumarização Capítulo 2:", resposta_sumarizacao_2)
for parte in partes_capitulo_23:
    parametros_23_2["messages"][1]["content"] = f"Texto do Capítulo 23: {parte} Pode resumir?"
    resposta_sumarizacao_23 = requests.post(endpoint, json=parametros_23_2, headers={"Authorization": f"Bearer {openai.api_key}"}).json()
    print("Resposta Sumarização Capítulo 23:", resposta_sumarizacao_23)
# Out:
# Resposta Sumarização Capítulo 2: {'id': 'chatcmpl-8Ozh7gQfVjv78RmUIrpjKGI8AiwIV', 'object': 'chat.completion', 'created': 1700967717, 'model': 'gpt-3.5-turbo-0613', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': 'Desculpe, mas não consigo resumir o conteúdo desse texto pois parece ser um código HTML. É necessário fornecer um texto em linguagem natural para que eu possa realizar a sumarização.'}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 634, 'completion_tokens': 45, 'total_tokens': 679}}
# ...

# %%
# TÉCNICA 3: TRADUÇÃO DE TEXTO PARA INGLÊS DO CAPÍTULO 2 E CAPÍTULO 3.
import openai
import requests
import json

openai.api_key = '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'
endpoint = "https://api.openai.com/v1/chat/completions"

def obter_texto_do_link(url):
    resposta = requests.get(url)
    texto = resposta.text
    return texto

#Necessário pelo mesmo motivo da técnica 1.
def dividir_texto_em_partes(texto, tamanho_maximo):
    partes = [texto[i:i+tamanho_maximo] for i in range(0, len(texto), tamanho_maximo)]
    return partes

capitulo_2_url = "https://brasileiraspln.com/livro-pln/1a-edicao/parte2/cap2/cap2.html"
capitulo_2_texto = obter_texto_do_link(capitulo_2_url)

capitulo_23_url = "https://brasileiraspln.com/livro-pln/1a-edicao/parte9/cap23/cap23.html"
capitulo_23_texto = obter_texto_do_link(capitulo_23_url)

mensagem_sistema_2_3 = "Você é um assistente de tradução de textos."
mensagem_usuario_2_3 = f"Texto do Capítulo 2: {capitulo_2_texto} Por favor, traduza para o inglês."
mensagem_assistente_2_3 = ""

parametros_2_3 = {
    "model": "gpt-3.5-turbo-0613",
    "messages": [
        {"role": "system", "content": mensagem_sistema_2_3},
        {"role": "user", "content": mensagem_usuario_2_3},
        {"role": "assistant", "content": mensagem_assistente_2_3}
    ]
}

mensagem_sistema_23_3 = "Você é um assistente de tradução de textos."
mensagem_usuario_23_3 = f"Texto do Capítulo 23: {capitulo_23_texto} Por favor, traduza para o inglês."
mensagem_assistente_23_3 = ""

parametros_23_3 = {
    "model": "gpt-3.5-turbo-0613",
    "messages": [
        {"role": "system", "content": mensagem_sistema_23_3},
        {"role": "user", "content": mensagem_usuario_23_3},
        {"role": "assistant", "content": mensagem_assistente_23_3}
    ]
}

partes_capitulo_2 = dividir_texto_em_partes(capitulo_2_texto, 2000)
partes_capitulo_23 = dividir_texto_em_partes(capitulo_23_texto, 2000)

# Enviar cada parte do texto como uma mensagem separada
for parte in partes_capitulo_2:
    parametros_2_3["messages"][1]["content"] = f"Texto do Capítulo 2: {parte} Por favor, traduza para o inglês."
    resposta_traducao_2 = requests.post(endpoint, json=parametros_2_3, headers={"Authorization": f"Bearer {openai.api_key}"}).json()
    print("Resposta Tradução do Capítulo 2:", resposta_traducao_2)

for parte in partes_capitulo_23:
    parametros_23_3["messages"][1]["content"] = f"Texto do Capítulo 23: {parte} Por favor, traduza para o inglês."
    resposta_traducao_23 = requests.post(endpoint, json=parametros_23_3, headers={"Authorization": f"Bearer {openai.api_key}"}).json()
    print("Resposta Tradução do Capítulo 23:", resposta_traducao_23)
# Out:
# Resposta Tradução do Capítulo 2: {'id': 'chatcmpl-8Ozhuz522LjU85hIup4nqENV6nUKL', 'object': 'chat.completion', 'created': 1700967766, 'model': 'gpt-3.5-turbo-0613', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': 'Chapter 2 Text: <!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml" lang="pt-BR" xml:lang="pt-BR"><head>\n\n<meta charset="utf-8">\n<meta name="generator" content="quarto-1.3.433">\n\n<meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=yes">\n\n<meta name="author" content="Camila de Araújo Azevedo">\n<meta name="author" content="Heliana Ribeiro de Mello">\n<meta name="author" content="Priscila Osório Côrtes">\n\n<title>Natural Language Processing - 2&nbsp; Text or Speech?</title>\n<style>\ncode{white-space: pre-wrap;}\nspan.smallcaps{font-variant: small-caps;}\ndiv.columns{display: flex; gap: min(4vw, 1.5em);}\ndiv.column{flex: auto; overflow-x: auto;}\ndiv.hanging-indent{margin-left: 1.5em; text-indent: -1.5em;}\
# ...
